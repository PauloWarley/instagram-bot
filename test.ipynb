# %%
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver import ActionChains, Keys
import uuid


from selenium_stealth import stealth

import pandas as pd

from selenium.webdriver.chrome.service import Service
import os

# %%
driver = None

userdata = f'--user-data-dir={os.getcwd()}/userdata/3768e0f3-b3e6-49eb-8545-c185013a6993'

service = Service(ChromeDriverManager().install())

# self.options.add_argument("--window-position=2000,0")
# self.options.add_argument("--window-size=1920,1080")
# self.options.add_argument("--headless")

options = webdriver.ChromeOptions()


options.add_argument(userdata)

driver = webdriver.Chrome(options=options, service=service)

actions = ActionChains(driver)

stealth(driver,
    languages=["en-US", "en"],
    vendor="Google Inc.",
    platform="Win32",
    webgl_vendor="Intel Inc.",
    renderer="Intel Iris OpenGL Engine",
    fix_hairline=True,
)
    
# self.driver.set_window_size(1920, 1080)
# self.driver.set_page_load_timeout(30)

# self.capa = DesiredCapabilities.CHROME
# self.capa["pageLoadStrategy"] = "none"

# self.driver = webdriver.Chrome(desired_capabilities=capa)
# self.driver.set_page_load_timeout(10)c

# %%
driver.get("https://www.instagram.com/p/C9A7IEABGAE/")

# %%
try:
    cookies = driver.get_cookies()
    
    f = open("cookies.json", "w")
    f.write(json.dumps(cookies))
    
    btn = driver.find_element(By.XPATH, ".//section/div/span/div/div[@role='button']//*[local-name() = 'svg' and @aria-label='Like']")
    actions.move_to_element(btn).perform()
    
    btn = driver.find_element(By.XPATH, ".//section/div/span/div/div[@role='button']//*[local-name() = 'svg' and @aria-label='Like']")
    
    # print(btn)
    btn.click()
except Exception as e:
    print("erro", time.time(), e)
# Out:
# erro 1720207589.0733175 Message: no such element: Unable to locate element: {"method":"xpath","selector":".//section/div/span/div/div[@role='button']//*[local-name() = 'svg' and @aria-label='Like']"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0071C1C3+27395]
# 	(No symbol) [0x006B3DC4]
# 	(No symbol) [0x005B1B7F]
# 	(No symbol) [0x005F2C65]
# 	(No symbol) [0x005F2D3B]
# 	(No symbol) [0x0062EC82]
# 	(No symbol) [0x006139E4]
# 	(No symbol) [0x0062CB24]
# 	(No symbol) [0x00613736]
# 	(No symbol) [0x005E7541]
# 	(No symbol) [0x005E80BD]
# 	GetHandleVerifier [0x009D3A93+2876371]
# 	GetHandleVerifier [0x00A27F5D+3221661]
# 	GetHandleVerifier [0x0079D634+556916]
# 	GetHandleVerifier [0x007A474C+585868]
# 	(No symbol) [0x006BCE04]
# 	(No symbol) [0x006B9818]
# 	(No symbol) [0x006B99B7]
# ...

# %%
driver_test = webdriver.Chrome(service=service)

actions = ActionChains(driver_test)
b
stealth(driver_test,
    languages=["en-US", "en"],
    vendor="Google Inc.",
    platform="Win32",
    webgl_vendor="Intel Inc.",
    renderer="Intel Iris OpenGL Engine",
    fix_hairline=True,
)

# %%
driver_test.get("https://www.instagram.com/p/C9A7IEABGAE/")

# %%
f = open("cookies.json","r")
cookies_ = json.loads(f.read())
cookies_
# Out:
# [{'domain': '.instagram.com',
#   'httpOnly': True,
#   'name': 'rur',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': True,
#   'value': '"VLL\\0545383204620\\0541751743570:01f78c945659067c6cb3477f14ac28dcbbd1d397b64541a2e23b294aad8a7950a5656926"'},
#  {'domain': '.instagram.com',
#   'expiry': 1751740686,
#   'httpOnly': True,
#   'name': 'sessionid',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': True,
#   'value': '5383204620%3AEXAxDf1ir44BET%3A4%3AAYc3UMOjUmDNdK-YIVKXfcN4IetzqXxzFLqAkwXruw'},
#  {'domain': '.instagram.com',
#   'expiry': 1754761728,
#   'httpOnly': True,
#   'name': 'ps_n',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': '1'},
#  {'domain': '.instagram.com',
#   'expiry': 1720812367,
#   'httpOnly': False,
#   'name': 'dpr',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': '1.25'},
#  {'domain': '.instagram.com',
#   'expiry': 1727983570,
#   'httpOnly': False,
#   'name': 'ds_user_id',
# ...

# %%
for cookie in cookies_:
    driver_test.add_cookie(cookie)

# %%
driver_test.get("https://www.instagram.com/p/C9A7IEABGAE/")

# %%
from pymongo import MongoClient

# String de conexão MongoDB
mongo_uri = "mongodb+srv://fanzo-manager-prod:zSCiM6QtpBMZmD8t@prod-fanzo.s5pj0hj.mongodb.net/social-media-service?retryWrites=true&w=majority"

# Função para conectar ao MongoDB
def connect_to_mongodb(uri):
    client = MongoClient(uri)
    return client

# Função para inserir um documento (create)
def insert_document(db, collection_name, document):
    collection = db[collection_name]
    result = collection.insert_one(document)
    return result

# Função para buscar documentos (get)
def find_documents(db, collection_name, query=None):
    collection = db[collection_name]
    if query:
        documents = collection.find(query)
    else:
        documents = collection.find()
    return list(documents)

# Função para atualizar um documento (update)
def update_document(db, collection_name, query, update):
    collection = db[collection_name]
    result = collection.update_one(query, {"$set": update})
    return result

# Exemplo de uso
if __name__ == "__main__":
    # Conectar ao MongoDB
    client = connect_to_mongodb(mongo_uri)
    db = client.get_database()

    # Exemplo de inserção (create)
    new_document = {
        "social_media": {
            "instagram": {
                "name": "instagram",
                "credentials": {
                    "user_name": "teste",
                    "cookies": "coookie"
                },
                "double_auth_code":{
                    "code": "012345",
                    "used": False
                }
            }
        }
    
    }
    insert_result = insert_document(db, "social", new_document)
    print(f"Inserido novo documento com ID: {insert_result.inserted_id}")

    # Exemplo de busca (get)
    # all_documents = find_documents(db, "social")
    # print("Todos os documentos na coleção 'social':")
    # for doc in all_documents:
    #     print(doc)

    # Exemplo de atualização (update)
    # update_query = {"name": "John Doe"}
    # update_data = {"$set": {"age": 31}}
    # update_result = update_document(db, "social", update_query, update_data)
    # print(f"Número de documentos atualizados: {update_result.modified_count}")

    # Fechar conexão
    client.close()
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[66], line 55
#      38 # Exemplo de inserção (create)
#      39 new_document = {
#      40     "social_media": {
#      41         "instagram": {
#    (...)
#      53
#      54 }
# ---> 55 insert_result = insert_document(db, "social", new_document)
#      56 print(f"Inserido novo documento com ID: {insert_result.inserted_id}")
#      58 # Exemplo de busca (get)
#      59 # all_documents = find_documents(db, "social")
#      60 # print("Todos os documentos na coleção 'social':")
#    (...)
#      69
#      70 # Fechar conexão
#
# Cell In[66], line 14, in insert_document(db, collection_name, document)
#      12 def insert_document(db, collection_name, document):
#      13     collection = db[collection_name]
# ---> 14     result = collection.insert_one(document)
#      15     return result
#
# ...

# %%
from pymongo import MongoClient

# String de conexão MongoDB
mongo_uri = "mongodb+srv://fanzo-manager-prod:zSCiM6QtpBMZmD8t@prod-fanzo.s5pj0hj.mongodb.net/social-media-service?retryWrites=true&w=majority"

class MongoDB():
    def __init__(self):
       pass
   
    # Função para conectar ao MongoDB
    def connect_to_mongodb(self, uri):
        client = MongoClient(uri)
        return client

    # Função para buscar documento pelo user_name
    def find_document_by_username(self, db, collection_name, username):
        collection = db[collection_name]
        query = {"social_media.instagram.credentials.user_name": username}
        document = collection.find_one(query)
        return document

    # Função para atualizar um documento
    def update_document(self, db, collection_name, query, update):
        collection = db[collection_name]
        result = collection.update_one(query, {"$set": update})
        return result



mongo = MongoDB()

# Conectar ao MongoDB
client = mongo.connect_to_mongodb(mongo_uri)
db = client.get_database()

# Exemplo de busca pelo user_name
username = "jn.desouza"
document = mongo.find_document_by_username(db, "social", username)

if document:
    print("Documento encontrado antes da atualização:")
    print(document)

    # Atualização do documento
    update_query = {"_id": document["_id"]}  # Supondo que você queira atualizar pelo ID
    cookie = "novo_cookie"  # Novo valor para atualizar
    update_data = {"social_media.instagram.credentials.cookies": cookie}
    update_result = mongo.update_document(db, "social", update_query, update_data)
    
    code = {
        "code": "123456",
        "used": False
    }
    update_data = {"social_media.instagram.credentials.code": code}
    update_result = mongo.update_document(db, "social", update_query, update_data)

    if update_result.modified_count > 0:
        print(f"Documento atualizado com sucesso. Novo valor para 'age': {cookie}")
    else:
        print("Nenhum documento foi atualizado.")
else:
    print(f"Nenhum documento encontrado com user_name '{username}'")

# Fechar conexão
client.close()
# Out:
# Documento encontrado antes da atualização:
# ...
